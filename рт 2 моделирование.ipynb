# %%
import numpy as np
import matplotlib.pyplot as plt

Ax = 1
Ay = 1
wx = 2
wy = 3

t = np.linspace(0, 2*np.pi, 1000)

x = Ax * np.sin(wx * t)
y = Ay * np.sin(wy * t)

# %%
plt.figure()
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.axis('equal')
plt.show()
